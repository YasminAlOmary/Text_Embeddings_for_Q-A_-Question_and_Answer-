# %%
# !pip install -q openai

# %%
import openai
import os

# %%
os.environ['OPENAI_API_KEY'] = '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'
openai.api_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## Document Data

# %%
import pandas as pd

# %%
df = pd.read_csv("unicorns.csv")

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Updated at                  1199 non-null   object
#  1   Company                     1199 non-null   object
#  2   Crunchbase Url              1199 non-null   object
#  3   Last Valuation (Billion $)  1199 non-null   float64
#  4   Date Joined                 1199 non-null   object
#  5   Year Joined                 1199 non-null   int64
#  6   City                        1181 non-null   object
#  7   Country                     1199 non-null   object
#  8   Industry                    1199 non-null   object
#  9   Investors                   1199 non-null   object
#  10  Company Website             0 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 103.2+ KB

# %% [markdown]
# ### create a new columns ("summary columns")

# %%
import ast

# %%
def summary(company, crunchbase_url, city, country, industry, investor_list):
  investors = "The investors in the company are "
  for investor in ast.literal_eval(investor_list):
      investors += f"{investor},"

  text = f"{company} has headquarters in {city} in {country} and is in the field of {industry}. {investors}. More info at {crunchbase_url}"

  return text

# %%
df['summary'] = df.apply(lambda df: summary(df['Company'],df['Crunchbase Url'],df['City'],df['Country'],df['Industry'],df['Investors']),axis=1)

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website  \
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
#
#                                              summary
# 0  Esusu has headquarters in New York in United S...
# 1  Fever Labs has headquarters in New York in Uni...
# 2  Minio has headquarters in Palo Alto in United ...
# 3  Darwinbox has headquarters in Hyderabad in Ind...
# 4  Pentera has headquarters in Petah Tikva in Isr...

# %%
import textwrap
text=df['summary'][1]
wrapped_text = textwrap.fill(text, width=100)
print(wrapped_text)
# Out:
# Fever Labs has headquarters in New York in United States and is in the field of Internet software &
# services. The investors in the company are Accel,14W,GS Growth,. More info at
# https://www.cbinsights.com/company/fever-labs

# %% [markdown]
# ## Token Count and Pricing

# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.1.31)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.1 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.9.0

# %%
import tiktoken

# %%
def num_tokens_from_string(string, encoding_name):
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokens_from_string(df['summary'][0], "cl100k_base")
# Out:
# 52

# %%
len(df['summary'][0].split())
# Out:
# 32

# %%
df["token_count"] = df['summary'].apply(lambda text: num_tokens_from_string(text, "cl100k_base"))

# %%
int(df["token_count"].sum())
# Out:
# 63363

# %%
# $0.0001 per 1k token USD
# total price for the text_embedding
float(df["token_count"].sum()*0.0001 /1000)
# Out:
# 0.0063363000000000004

# %%
def get_embedding(text):
    response = openai.embeddings.create(
        input=text,
        model='text-embedding-ada-002'
    )
    return response.data[0].embedding

# %%
vector = get_embedding("Esusu has headquarters in New York in United States and is in the field of Fintech. SoftBank Group SoftBank Group,. Nore info at https://www.cbinsights.com/company/esusu")

# %%
len(vector)
# Out:
# 1536

# %%
df['embedding'] = df['summary'].apply(get_embedding)

# %%
df
# Out:
#                   Updated at     Company  \
# 0     10/31/2022, 2:37:05 AM       Esusu
# 1     10/31/2022, 2:37:05 AM  Fever Labs
# 2     10/31/2022, 2:37:04 AM       Minio
# 3     10/31/2022, 2:37:04 AM   Darwinbox
# 4     10/31/2022, 2:37:04 AM     Pentera
# ...                      ...         ...
# 1194  10/31/2022, 2:32:42 AM    Fanatics
# 1195  10/31/2022, 2:32:38 AM      SpaceX
# 1196  10/31/2022, 2:33:10 AM  Vice Media
# 1197  10/31/2022, 2:33:05 AM      Klarna
# 1198  10/31/2022, 2:35:27 AM      Veepee
#
#                                          Crunchbase Url  \
# 0              https://www.cbinsights.com/company/esusu
# 1         https://www.cbinsights.com/company/fever-labs
# 2              https://www.cbinsights.com/company/minio
# 3          https://www.cbinsights.com/company/darwinbox
# 4             https://www.cbinsights.com/company/pcysys
# ...                                                 ...
# 1194        https://www.cbinsights.com/company/fanatics
# 1195  https://www.cbinsights.com/company/space-explo...
# 1196      https://www.cbinsights.com/company/vice-media
# 1197          https://www.cbinsights.com/company/klarna
# 1198    https://www.cbinsights.com/company/vente-privee
#
#       Last Valuation (Billion $) Date Joined  Year Joined  \
# 0                           1.00   1/27/2022         2022
# 1                           1.00   1/26/2022         2022
# 2                           1.00   1/26/2022         2022
# 3                           1.00   1/25/2022         2022
# 4                           1.00   1/11/2022         2022
# ...                          ...         ...          ...
# 1194                       27.00    6/6/2012         2012
# 1195                      127.00   12/1/2012         2012
# 1196                        5.70    4/2/2011         2011
# 1197                        6.70  12/12/2011         2011
# 1198                        1.38    7/2/2007         2007
#
#                        City        Country                         Industry  \
# 0                  New York  United States                          Fintech
# 1                  New York  United States     Internet software & services
# 2                 Palo Alto  United States      Data management & analytics
# 3                 Hyderabad          India     Internet software & services
# 4               Petah Tikva         Israel                   Cybersecurity
# ...                     ...            ...                              ...
# 1194           Jacksonville  United States  E-commerce & direct-to-consumer
# 1195              Hawthorne  United States                            Other
# 1196               Brooklyn  United States     Internet software & services
# 1197              Stockholm         Sweden                          Fintech
# 1198  La Plaine Saint-Denis         France  E-commerce & direct-to-consumer
#
#                                               Investors  Company Website  \
# 0     ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                           ["Accel","14W","GS Growth"]              NaN
# 2     ["General Catalyst","Nexus Venture Partners","...              NaN
# 3     ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4      ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
# ...                                                 ...              ...
# 1194  ["SoftBank Group","Andreessen Horowitz","Temas...              NaN
# 1195  ["Founders Fund","Draper Fisher Jurvetson","Ro...              NaN
# 1196  ["Technology Crossover Ventures","A&E Televisi...              NaN
# 1197  ["Institutional Venture Partners","Sequoia Cap...              NaN
# 1198                ["Summit Partners","Qatar Holding"]              NaN
#
#                                                 summary  token_count  \
# 0     Esusu has headquarters in New York in United S...           52
# 1     Fever Labs has headquarters in New York in Uni...           53
# 2     Minio has headquarters in Palo Alto in United ...           51
# 3     Darwinbox has headquarters in Hyderabad in Ind...           56
# 4     Pentera has headquarters in Petah Tikva in Isr...           53
# ...                                                 ...          ...
# 1194  Fanatics has headquarters in Jacksonville in U...           57
# 1195  SpaceX has headquarters in Hawthorne in United...           59
# 1196  Vice Media has headquarters in Brooklyn in Uni...           50
# 1197  Klarna has headquarters in Stockholm in Sweden...           51
# 1198  Veepee has headquarters in La Plaine Saint-Den...           57
#
#                                               embedding
# 0     [0.011081160977482796, -0.018728159368038177, ...
# 1     [0.008602230809628963, 0.011036576703190804, -...
# 2     [0.005523009225726128, -0.04294928163290024, 0...
# 3     [-6.426063919207081e-05, -0.02552231401205063,...
# 4     [0.011503264307975769, -0.01382159348577261, 0...
# ...                                                 ...
# 1194  [-0.0017611222574487329, -0.012050825171172619...
# 1195  [0.02533082477748394, -0.014380521140992641, -...
# 1196  [0.007336130365729332, -0.03166935220360756, 0...
# 1197  [0.026691757142543793, -0.025004049763083458, ...
# 1198  [0.001280086813494563, -0.012835531495511532, ...
#
# [1199 rows x 14 columns]

# %%
df.to_csv('my_embedding.csv')

# %% [markdown]
# ## Document Similarity and Context Injection

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website  \
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
#
#                                              summary  token_count  \
# 0  Esusu has headquarters in New York in United S...           52
# 1  Fever Labs has headquarters in New York in Uni...           53
# 2  Minio has headquarters in Palo Alto in United ...           51
# 3  Darwinbox has headquarters in Hyderabad in Ind...           56
# 4  Pentera has headquarters in Petah Tikva in Isr...           53
#
#                                            embedding
# 0  [0.011081160977482796, -0.018728159368038177, ...
# 1  [0.008602230809628963, 0.011036576703190804, -...
# 2  [0.005523009225726128, -0.04294928163290024, 0...
# 3  [-6.426063919207081e-05, -0.02552231401205063,...
# 4  [0.011503264307975769, -0.01382159348577261, 0...

# %%
prompt = "What does the company Minio do and where is the HQ?"

#  0.020041363313794136,
#  0.03768055513501167,
#  0.002948594279587269,
#  -0.0156560055911541,
#  -0.0009819918777793646,
#  -0.004322510212659836,
#  0.00174663623329252,
#  -0.00950393546372652,
#  -0.005638815928250551,
#  -0.0028246452566236258,
#  -0.016996752470731735,
#  0.0070459009148180485,
#  0.024845704436302185,
#  -0.02768082357943058,
#  -0.0337979793548584,
#  0.008456477895379066,
#  -0.016926921904087067,
#  0.01978997327387333,
#  ...]

# %%
import numpy as np

# %%
from sklearn.metrics.pairwise import cosine_similarity
def vector_similarity(vec1, vec2):
    return cosine_similarity([vec1], [vec2])[0][0]

# %%
df['prompt_similarity'] = df['embedding'].apply(lambda vector:vector_similarity(vector, prompt_embedding))

# %%
df['prompt_similarity']
# Out:
# 0       0.734976
# 1       0.736571
# 2       0.885993
# 3       0.758952
# 4       0.748027
#           ...
# 1194    0.738153
# 1195    0.752419
# 1196    0.758349
# 1197    0.756377
# 1198    0.742619
# Name: prompt_similarity, Length: 1199, dtype: float64

# %%
df.head()
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website  \
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
#
#                                              summary  token_count  \
# 0  Esusu has headquarters in New York in United S...           52
# 1  Fever Labs has headquarters in New York in Uni...           53
# 2  Minio has headquarters in Palo Alto in United ...           51
# 3  Darwinbox has headquarters in Hyderabad in Ind...           56
# 4  Pentera has headquarters in Petah Tikva in Isr...           53
#
#                                            embedding  prompt_similarity
# 0  [0.011081160977482796, -0.018728159368038177, ...           0.734976
# 1  [0.008602230809628963, 0.011036576703190804, -...           0.736571
# 2  [0.005523009225726128, -0.04294928163290024, 0...           0.885993
# 3  [-6.426063919207081e-05, -0.02552231401205063,...           0.758952
# 4  [0.011503264307975769, -0.01382159348577261, 0...           0.748027

# %%
df.nlargest(1, 'prompt_similarity')
# Out:
#                Updated at Company                            Crunchbase Url  \
# 2  10/31/2022, 2:37:04 AM   Minio  https://www.cbinsights.com/company/minio
#
#    Last Valuation (Billion $) Date Joined  Year Joined       City  \
# 2                         1.0   1/26/2022         2022  Palo Alto
#
#          Country                     Industry  \
# 2  United States  Data management & analytics
#
#                                            Investors  Company Website  \
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
#
#                                              summary  token_count  \
# 2  Minio has headquarters in Palo Alto in United ...           51
#
#                                            embedding  prompt_similarity
# 2  [0.005523009225726128, -0.04294928163290024, 0...           0.885993

# %% [markdown]
# ###### Now we can easily grab the summary for the most similar embedding, then insert that as context to our GPT request!

# %%
df.nlargest(1, 'prompt_similarity').iloc[0]['summary']
# Out:
# 'Minio has headquarters in Palo Alto in United States and is in the field of Data management & analytics. The investors in the company are General Catalyst,Nexus Venture Partners,Dell Technologies Capital,. More info at https://www.cbinsights.com/company/minio'

# %% [markdown]
# ## Question Answering with Embeddings

# %%
Context = df.nlargest(1, 'prompt_similarity').iloc[0]['summary']

# %%
prompt = f''' Only answer the question below if you have 100% certainty of the facts.
Context : {Context}
Q: What does the start-up company Pentera do and who invested in it?
A:
'''

# %%
print(prompt)
# Out:
#  Only answer the question below if you have 100% certainty of the facts.
# Context : Minio has headquarters in Palo Alto in United States and is in the field of Data management & analytics. The investors in the company are General Catalyst,Nexus Venture Partners,Dell Technologies Capital,. More info at https://www.cbinsights.com/company/minio
# Q: What does the start-up company Pentera do and who invested in it?
# A:

# %%
response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=0,
    max_tokens=512
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-BRph5Q9n0tPeAb5uiSqI2kDEInWTY', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='I cannot answer that question as it is not related to the information provided about Minio.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1745973267, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=97, total_tokens=116, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
response.choices[0].message.content
# Out:
# 'I cannot answer that question as it is not related to the information provided about Minio.'

# %%
prompt = f''' Only answer the question below if you have 100% certainty of the facts.
Context : {Context}
Q: What does the start-up company Fever Labs do and who invested in it?
A:
'''

# %%
response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=0,
    max_tokens=512
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-BRpk8RdVDrBH6SM0kqFJt4fIam8et', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="I'm sorry, I cannot provide information on Fever Labs as it is not related to Minio.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1745973456, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=21, prompt_tokens=96, total_tokens=117, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
response.choices[0].message.content
# Out:
# "I'm sorry, I cannot provide information on Fever Labs as it is not related to Minio."
